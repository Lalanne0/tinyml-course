# %% [markdown]
# <img src="https://datascientest.fr/train/assets/logo_datascientest.png" style="height:150px">
#
# <hr style="border-width:2px;border-color:#75DFC1">
# <center><h1> Titre du Module </h1></center>
# <center><h2> Titre du Notebook </h2></center>
# <hr style="border-width:2px;border-color:#75DFC1">
#
# >
# > Introduction : présentez le sujet en **quelques phrases**.
# >
# >
# > **Aérez** votre texte. Dans la mesure du possible, **revenez à la ligne** (avec 2 chevrons >) toutes les 1 ou 2 lignes.
# >
# >
# > Au sein de la partie "cours", **la marge doit être continue** (le chevron est donc indispensable au début de chaque ligne).
#
# # 1. Première partie
#
# ### Polices
# >
# > Voici les consignes concernant les **polices** :
# >
# > * Les éléments **importants** de votre texte doivent être mis en **gras**.
# >
# > * Les **anglicismes** doivent être mis en *italic*.
# >
# > * Dans une phrase, les fonctions/noms de variables/mots clés/etc doivent être au format `code` (et ce quel que soit l'outil dont on parle : Python/SQL/Outil DE/Outil de BI/etc). Par exemple :
# >
# >> * Voici la fonction `SELECT` du langage `SQL`.
# >> * Cliquer sur le bouton `Transform Data` pour accéder à `Power Query`.
# >
# > * Les longs paragraphes de code doivent être mis dans un **bloc de code** (pour avoir les couleurs).
# >
# >```python
# >for letter in "boucle":
# >    print(letter)
# >>>> b
# >>>> o
# >>>> u
# >>>> c
# >>>> l
# >>>> e
# >```
# >
# > * Dans une phrase, toute **formule mathématique** doit être en Latex (entre dollars) : $M_{i,j} = i^j$
# >
# > * Pour les longues formules ou les formules primordiales, mettre 2 dollars permet de centrer
# >
# > $$P(\rho | \theta , \kappa) = \frac{P(\theta | \rho , \kappa) P(\rho | \kappa)}{P(\theta |\kappa)}$$

# %% [markdown]
# <div class="alert alert-success">
# <i class="fa fa-question-circle"></i> &emsp;
# Pour donner des infos en plus.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <i class="fa fa-info-circle"></i> &emsp;
# Pour faire une remarque annexe.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <i class='fa fa-exclamation-triangle '></i> &emsp;
#   <strong>Attention</strong> Pour attirer l'attention sur un point.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <i class='fa fa-exclamation-circle'></i> &emsp;
#   <strong>Danger !</strong> Pour avertir d'un danger potentiel.
# </div>

# %% [markdown]
# <div class="alert alert-secondary">
# <i class="fa fa-lightbulb-o"></i> &emsp;
# <strong>Astuce</strong> : Pour rendre vos notebooks plus lisibles, commentez vos étapes clés dans le code.
# </div>

# %% [markdown]
# <div style="background:#EEF7FF;border-left:6px solid #2C77D6;padding:10px;color:#000000;">
# <i class="fa fa-book"></i> &emsp;
# <strong>Définition :</strong> Une <em>feature</em> correspond à une variable explicative dans un modèle.
# </div>

# %% [markdown]
# <div style="background:#F6FFF0;border-left:6px solid #5CB85C;padding:10px;color:#000000;">
# <i class="fa fa-thumb-tack"></i> &emsp;
# <strong>À retenir :</strong> Les modèles supervisés nécessitent une variable cible.
# </div>

# %% [markdown]
# <div style="background:#FBF8FF;border-left:6px solid #9A4DFF;padding:10px;color:#000000;">
# <i class="fa fa-pencil"></i> &emsp;
# <strong>Exemple :</strong> Application de la normalisation sur une colonne.
# </div>

# %% [markdown]
# <div style="background:#FFF7E6;border-left:6px solid #E67E22;padding:10px;color:#000000;">
# <i class="fa fa-bug"></i> &emsp;
# <strong>Erreur fréquente :</strong> Ne jamais normaliser la variable cible d’un modèle de classification !
# </div>

# %% [markdown]
# <div style="background:#E6F3FF;border-left:6px solid #007BFF;padding:10px;color:#000000;">
# <i class="fa fa-bullseye"></i> &emsp;
# <strong>Objectif :</strong> Comprendre l’algorithme <em>KNN</em> et l’utiliser dans `sklearn`.
# </div>

# %% [markdown]
# <div style="background:#FFF0F5;border-left:6px solid #D9467A;padding:10px;color:#000000;">
# <i class="fa fa-rocket"></i> &emsp;
# <strong>Pour aller plus loin :</strong> Lire la documentation `PCA` d’`sklearn`.
# </div>

# %% [markdown]
# ><small>*Remarque : Il existe de nombreux [algorithmes d'optimisation](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers).*</small>

# %% [markdown]
# ### Autre
#
# > Voici le code pour insérer une image/vidéo/gif (il faut l'upload sur le s3 en **public** et intégrer le lien dans cette balise html).
# >
# > <center><img src="https://assets-datascientest.s3.eu-west-1.amazonaws.com/autoencoder_swiss_roll.png" style="height:200px"></center>
# > <i><center>avec une légende centrée pour l'image</center></i>
# >
# > Voici le code pour insérer un tableau.
# >
# > | Clé        |      Valeur |
# > | ---------- | ----------- |
# > |`"age"`     | `25`        |
# > |`"taille"`  | `183`       |
# > | `"sexe"`   | `"F"`       |
# > | `"prenom"` | `"Vanessa"` |
# >
# > Vous pouvez aussi ajouter une deuxième marge pour donner du relief :
# >
# > > Requête: "Je suis venu au bureau en voiture. Où aurais-je pu laisser les clés de ma voiture?".
# > >
# > > Valeurs:
# > > * A: "Dans mon pantalon."
# > > * B: "À Disneyland."
# > > * C: "Au bureau."
# > > * D: "En Espagne."
# >
# > Vous pouvez aussi ajouter des [*liens*](https://www.youtube.com/watch?v=dQw4w9WgXcQ&ab_channel=RickAstley), en particulier pour rediriger vers la doc.
# >
# > Si vous voulez demander aux apprenants d'exécuter une cellule pré-codée :
#
# * **(a)** Exécuter la cellule suivante.

# %%
for letter in "boucle":
    print(letter)

# %% [markdown]
# Pour un QCM :
#
# %%QCM%%
# {
#   "title": "Question 1",
#   "question": "Qu'est-ce que Git ?",
#   "answers": [
#     {
#       "text": "Un système de gestion de versions",
#       "correction": "",
#       "correct": True
#     },
#     {
#       "text": "Un logiciel de retouche d'image",
#       "correction": "",
#       "correct": False
#     },
#     {
#       "text": "Un éditeur de texte",
#       "correction": "",
#       "correct": False
#     }
#   ]
# }
# %%QCM%%
#
# %%SOLUTION%%
#
# voici la solution.
#
# %%SOLUTION%%
#
# %%QCM%%
# {
#   "title": "Question 2",
#   "question": "Comment crée-t-on un nouveau référentiel Git ?",
#   "answers": [
#     {
#       "text": "git init",
#       "correction": "",
#       "correct": True
#     },
#     {
#       "text": "git clone",
#       "correction": "",
#       "correct": False
#     },
#     {
#       "text": "git branch",
#       "correction": "",
#       "correct": False
#     }
#   ]
# }
# %%QCM%%
